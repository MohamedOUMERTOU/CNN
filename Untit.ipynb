# %%
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
img=cv2.imread('img4.jpeg')

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
lower=np.array([148,70,110])
higher=np.array([250,250,250])

# %%
mask=cv2.inRange(img,lower,higher)
plt.imshow(mask,'gray')

# %%
cont,_=cv2.findContours(mask,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
cont_img=cv2.drawContours(img,cont,-1,255,3)
plt.imshow(cont_img)

# %%
c=max(cont,key=cv2.contourArea)
x,y,w,h=cv2.boundingRect(c)
cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),5)
plt.imshow(img)

# %%
cropped_image=img[y:y+h,x:x+w]
plt.imshow(cropped_image)

# %%
rect = cv2.minAreaRect(cont[0])
box = cv2.boxPoints(rect)
box = np.int0(box)
cv2.drawContours(img,[box],0,(0,0,255),2)
# Out:
# C:\Users\OUAZZE M\AppData\Local\Temp\ipykernel_2148\1481437472.py:3: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   box = np.int0(box)
# array([[[ 65,  35,  27],
#         [ 65,  35,  27],
#         [ 65,  34,  29],
#         ...,
#         [ 91,  54,  46],
#         [ 88,  53,  47],
#         [ 88,  53,  47]],
#
#        [[ 65,  35,  27],
#         [ 65,  35,  27],
#         [ 65,  34,  29],
#         ...,
#         [ 91,  54,  46],
#         [ 88,  53,  47],
#         [ 88,  53,  47]],
#
#        [[ 65,  35,  27],
#         [ 65,  35,  27],
#         [ 65,  34,  29],
#         ...,
#         [ 91,  54,  46],
#         [ 88,  53,  47],
#         [ 88,  53,  47]],
#
#        ...,
#
#        [[114,  61,  53],
#         [115,  62,  54],
#         [117,  64,  58],
#         ...,
#         [169, 116,  85],
#         [169, 114,  84],
#         [169, 114,  84]],
#
#        [[114,  61,  53],
#         [115,  62,  54],
#         [116,  63,  57],
#         ...,
#         [169, 116,  85],
#         [169, 114,  84],
#         [169, 114,  84]],
#
#        [[112,  59,  51],
#         [113,  60,  52],
#         [115,  62,  56],
#         ...,
#         [169, 116,  85],
#         [169, 114,  84],
#         [169, 114,  84]]], dtype=uint8)

# %%
cv2.imshow("test", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
